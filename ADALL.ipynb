# %% [markdown]
# <a href="https://colab.research.google.com/github/a81134866-lgtm/ADALL_github/blob/main/ADALL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("HelloWorld")
# Out:
# HelloWorld
